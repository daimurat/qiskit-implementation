# %%
from qiskit.visualization import plot_bloch_vector

# %%
plot_bloch_vector([0, 1, 0])
# Out:
# C:\Users\DaikiMurata\Anaconda3\envs\qiskit\lib\site-packages\qiskit\visualization\bloch.py:402: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   self.axes = Axes3D(self.fig, azim=self.view[0], elev=self.view[1])
# C:\Users\DaikiMurata\Anaconda3\envs\qiskit\lib\site-packages\qiskit\visualization\bloch.py:69: MatplotlibDeprecationWarning:
# The M attribute was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use self.axes.M instead.
#   x_s, y_s, _ = proj3d.proj_transform(xs3d, ys3d, zs3d, renderer.M)
