# %% [markdown]
# # Fundamentals of Quantum Computation Using Qiskit v0.2X Developer

# %%
import matplotlib as plt
import numpy
import math
from qiskit import QuantumCircuit, QuantumRegister, assemble, Aer, BasicAer, execute
from qiskit.quantum_info import Statevector, state_fidelity, average_gate_fidelity, process_fidelity, hellinger_fidelity
from qiskit.quantum_info.operators import Operator
from qiskit.visualization import plot_histogram
from qiskit.extensions import XGate

# %%
import qiskit.tools.jupyter
# %qiskit_version_table
# Out:
# C:\Users\DaikiMurata\anaconda3\lib\site-packages\qiskit\aqua\operators\operator_globals.py:48: DeprecationWarning: `from_label` is deprecated and will be removed no earlier than 3 months after the release date. Use Pauli(label) instead.
#   X = make_immutable(PrimitiveOp(Pauli.from_label('X')))
# <h3>Version Information</h3><table><tr><th>Qiskit Software</th><th>Version</th></tr><tr><td>Qiskit</td><td>0.25.3</td></tr><tr><td>Terra</td><td>0.17.1</td></tr><tr><td>Aer</td><td>0.7.2</td></tr><tr><td>Ignis</td><td>0.5.1</td></tr><tr><td>Aqua</td><td>0.8.1</td></tr><tr><td>IBM Q Provider</td><td>0.11.1</td></tr><tr><th>System information</th></tr><tr><td>Python</td><td>3.7.9 (default, Aug 31 2020, 17:10:11) [MSC v.1916 64 bit (AMD64)]</td></tr><tr><td>OS</td><td>Windows</td></tr><tr><td>CPUs</td><td>4</td></tr><tr><td>Memory (Gb)</td><td>29.88125991821289</td></tr><tr><td colspan='2'>Sat May 15 23:31:43 2021  (W)</td></tr></table>

# %% [markdown]
# ## 1
# Which statement will create a quantum circuit with four quantum bits and four classical bits?

# %%
qc = QuantumCircuit(4, 4)
qc.draw('mpl')

# %%
qc = QuantumCircuit(4)
qc.draw('mpl')

# %%
qc = QuantumCircuit(QuantumRegister(4, 'qr0'), QuantumRegister(4, 'crl'))
qc.draw('mpl')

# %%
qc = QuantumCircuit([4, 4])
qc.draw('mpl')
# Out:
# ---------------------------------------------------------------------------
# CircuitError                              Traceback (most recent call last)
# <ipython-input-6-2adc02cb431e> in <module>
# ----> 1 qc = QuantumCircuit([4, 4])
#       2 qc.draw('mpl')
#
# ~\anaconda3\lib\site-packages\qiskit\circuit\quantumcircuit.py in __init__(self, name, global_phase, metadata, *regs)
#     189         self._ancillas = []
#     190         self._calibrations = defaultdict(dict)
# --> 191         self.add_register(*regs)
#     192
#     193         # Parameter table tracks instructions with variable parameters.
#
# ~\anaconda3\lib\site-packages\qiskit\circuit\quantumcircuit.py in add_register(self, *regs)
#    1120                 self._clbit_set.update(new_bits)
#    1121             elif isinstance(register, list):
# -> 1122                 self.add_bits(register)
#    1123             else:
#    1124                 raise CircuitError("expected a register")
#
# ~\anaconda3\lib\site-packages\qiskit\circuit\quantumcircuit.py in add_bits(self, bits)
#    1143             else:
#    1144                 raise CircuitError("Expected an instance of Qubit, Clbit, or "
# -> 1145                                    "AncillaQubit, but was passed {}".format(bit))
#    1146
#    1147     def _check_dups(self, qubits):
#
# CircuitError: 'Expected an instance of Qubit, Clbit, or AncillaQubit, but was passed 4'

# %% [markdown]
# # 2
# Given this code fragment, what is the probability that a measurement would result in |0> ?
# ```
# qc = QuantumCircuit(1)
# qc.ry(3 * math.pi/4, 0)
# ```

# %%
qc = QuantumCircuit(1,1)
qc.ry(3 * math.pi/4, 0)
qc.measure(0,0)
qc.draw('mpl')

# %%
qasmsim = Aer.get_backend('qasm_simulator')
qobj = assemble(qc)  # Assemble circuit into a Qobj that can be run
counts = qasmsim.run(qobj).result().get_counts()  # Do the simulation, returning the state vector
plot_histogram(counts)  # Display the output state vector

# %% [markdown]
# # 3
# Assuming the fragment below, which three code fragments would produce the circuit illustrated?

# %%
inp_reg = QuantumRegister(2, name='inp')
ancilla = QuantumRegister(1, name='anc')
qc = QuantumCircuit(inp_reg, ancilla)
qc.h(inp_reg[0:2])
qc.x(ancilla[0])
qc.draw('mpl')

# %% [markdown]
# # 4
# Given an empty QuantumCircuit object, qc, with three qubits and three classical bits, which one of these code fragments would create this circuit?

# %%
qc = QuantumCircuit(3, 3)
qc.measure([0,1,2], [0,1,2])
qc.draw('mpl')

# %% [markdown]
# `measure_all()`は古典レジスタを新たに生成するためこの問いでは不適。

# %%
qc = QuantumCircuit(3, 3)
qc.measure_all()
qc.draw('mpl')

# %% [markdown]
# # 5
# Which code fragment will produce a maximally entangled, or Bell, state?

# %%
bell = QuantumCircuit(2)
bell.h(0)
bell.x(1)
bell.cx(0, 1)
bell.draw('mpl')

# %% [markdown]
# # 8
# Which two code fragments, when inserted into the code below, will produce the statevector shown in the output?
# ```
# from qiskit import QuantumCircuit, Aer, execute
# from math import sqrt
# qc = QuantumCircuit(2)
# # Insert fragment here
# simulator = Aer.get_backend('statevector_simulator')
# result = execute(qc, simulator).result()
# statevector = result.get_statevector()
# print(statevector)
# ```
# Output:
# `[0.707+0.j 0.+0.j 0.+0.j 0.707+0.j]`

# %%
qc = QuantumCircuit(2)
v = [1/math.sqrt(2), 0, 0, 1/math.sqrt(2)]
qc.initialize(v, [0,1])

simulator = Aer.get_backend('statevector_simulator')
result = execute(qc, simulator).result()
statevector = result.get_statevector()
print(statevector)
# Out:
# [0.70710678+0.j 0.        +0.j 0.        +0.j 0.70710678+0.j]

# %% [markdown]
# # 11
# Which two options would place a barrier across all qubits to the QuantumCircuit below?
# ```
# qc = QuantumCircuit(3,3)
# ```

# %%
qc= QuantumCircuit(3, 3)
qc.barrier()
qc.draw('mpl')

# %%
qc= QuantumCircuit(3, 3)
qc.barrier(qc)
qc.draw('mpl')

# %%
qc= QuantumCircuit(3, 3)
qc.barrier(3)
qc.draw('mpl')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\qiskit\circuit\quantumcircuit.py in _bit_argument_conversion(bit_representation, in_array)
#     923                 # circuit.h(0) -> circuit.h([qr[0]])
# --> 924                 ret = [in_array[bit_representation]]
#     925             elif isinstance(bit_representation, slice):
#
# IndexError: list index out of range
#
# The above exception was the direct cause of the following exception:
#
# CircuitError                              Traceback (most recent call last)
# <ipython-input-13-39b33724dc30> in <module>
#       1 qc= QuantumCircuit(3, 3)
# ----> 2 qc.barrier(3)
#       3 qc.draw('mpl')
#
# ~\anaconda3\lib\site-packages\qiskit\circuit\quantumcircuit.py in barrier(self, *qargs)
#    2197                 qubits.append(qarg)
#    2198
# -> 2199         return self.append(Barrier(len(qubits)), qubits, [])
#    2200
#    2201     def delay(self, duration, qarg=None, unit='dt'):
#
# ~\anaconda3\lib\site-packages\qiskit\circuit\quantumcircuit.py in append(self, instruction, qargs, cargs)
#    1006                 instruction = copy.deepcopy(instruction)
#    1007
# -> 1008         expanded_qargs = [self.qbit_argument_conversion(qarg) for qarg in qargs or []]
#    1009         expanded_cargs = [self.cbit_argument_conversion(carg) for carg in cargs or []]
#    1010
#
# ~\anaconda3\lib\site-packages\qiskit\circuit\quantumcircuit.py in <listcomp>(.0)
#    1006                 instruction = copy.deepcopy(instruction)
#    1007
# -> 1008         expanded_qargs = [self.qbit_argument_conversion(qarg) for qarg in qargs or []]
#    1009         expanded_cargs = [self.cbit_argument_conversion(carg) for carg in cargs or []]
#    1010
#
# ~\anaconda3\lib\site-packages\qiskit\circuit\quantumcircuit.py in qbit_argument_conversion(self, qubit_representation)
#     958             List(tuple): Where each tuple is a qubit.
#     959         """
# --> 960         return QuantumCircuit._bit_argument_conversion(qubit_representation, self.qubits)
#     961
#     962     def cbit_argument_conversion(self, clbit_representation):
#
# ~\anaconda3\lib\site-packages\qiskit\circuit\quantumcircuit.py in _bit_argument_conversion(bit_representation, in_array)
#     940                                                                      type(bit_representation)))
#     941         except IndexError as ex:
# --> 942             raise CircuitError('Index out of range.') from ex
#     943         except TypeError as ex:
#     944             raise CircuitError(
#
# CircuitError: 'Index out of range.'

# %% [markdown]
# # 13
# Given the following code, what is the depth of the circuit?
# ```
# qc = QuantumCircuit(2, 2)
# qc.h(0)
# qc.barrier(0)
# qc.cx(0,1)
# qc.barrier([0,1])
# ```

# %% [markdown]
# The depth of a circuit is a metric that calculates the longest path between the data input and the output.
#
# ref. https://medium.com/arnaldo-gunzi-quantum/how-to-calculate-the-depth-of-a-quantum-circuit-in-qiskit-868505abc104

# %%
qc = QuantumCircuit(2, 2) 
qc.h(0)
qc.barrier(0)
qc.cx(0,1)
qc.barrier([0,1])
qc.draw('mpl')

# %%
print("Circuit depth: ", qc.depth())
# Out:
# Circuit depth:  2

# %% [markdown]
# # 14
# Which code snippet would execute a circuit given these parameters?
#
# 1. Measure the circuit 1024 times,
# 2. use the QASM simulator,
# 3. and use a coupling map that connects three qubits linearly
# ```
# qc = QuantumCircuit(3)
# # Insert code fragment here
# result = job.result()
# ```

# %%
qc = QuantumCircuit(3)

# Insert code fragment here
qasm_sim = Aer.get_backend('qasm_simulator')
couple_map = [[0, 1], [1, 2]]
job = execute(qc, backend=qasm_sim, shots=1024, coupling_map=couple_map)

result = job.result()
print(result)
# Out:
# Result(backend_name='qasm_simulator', backend_version='0.7.2', qobj_id='f864f7ee-109e-4d64-8fbb-e716d483895a', job_id='5955e425-398a-4afc-8c59-5973c51c2a8f', success=True, results=[ExperimentResult(shots=1024, success=True, meas_level=MeasLevel.CLASSIFIED, data=ExperimentResultData(), header=QobjExperimentHeader(clbit_labels=[], creg_sizes=[], global_phase=0.0, memory_slots=0, metadata=None, n_qubits=3, name='circuit-103', qreg_sizes=[['q', 3]], qubit_labels=[['q', 0], ['q', 1], ['q', 2]]), status=DONE, seed_simulator=2573372209, time_taken=0.000144, metadata={'fusion': {'enabled': False}, 'measure_sampling': True, 'method': 'stabilizer', 'parallel_shots': 1, 'parallel_state_update': 8})], date=2021-05-15T23:32:00.268820, status=COMPLETED, status=QobjHeader(backend_name='qasm_simulator', backend_version='0.7.2'), metadata={'max_memory_mb': 15299, 'omp_enabled': True, 'parallel_experiments': 1, 'time_taken': 0.0002942}, time_taken=0.0009946823120117188)

# %%
qc = QuantumCircuit(3)

# Insert code fragment here
qasm_sim = Aer.get_backend('ibmq_simulator')
couple_map = [[0, 1], [0, 2]]
job = execute(qc, loop=1024, coupling_map=couple_map)

result = job.result()
print(result)
# Out:
# ---------------------------------------------------------------------------
# QiskitBackendNotFoundError                Traceback (most recent call last)
# <ipython-input-17-77ef33c34380> in <module>
#       2
#       3 # Insert code fragment here
# ----> 4 qasm_sim = Aer.get_backend('ibmq_simulator')
#       5 couple_map = [[0, 1], [0, 2]]
#       6 job = execute(qc, loop=1024, coupling_map=couple_map)
#
# ~\anaconda3\lib\site-packages\qiskit\providers\aer\aerprovider.py in get_backend(self, name, **kwargs)
#      39
#      40     def get_backend(self, name=None, **kwargs):
# ---> 41         return super().get_backend(name=name, **kwargs)
#      42
#      43     def backends(self, name=None, filters=None, **kwargs):
#
# ~\anaconda3\lib\site-packages\qiskit\providers\baseprovider.py in get_backend(self, name, **kwargs)
#      42             raise QiskitBackendNotFoundError('More than one backend matches the criteria')
#      43         if not backends:
# ---> 44             raise QiskitBackendNotFoundError('No backend matches the criteria')
#      45
#      46         return backends[0]
#
# QiskitBackendNotFoundError: 'No backend matches the criteria'

# %%
qc = QuantumCircuit(3)

# Insert code fragment here
qasm_sim = Aer.get_backend('qasm_simulator')
couple_map = [[0, 1], [1, 2]]
job = execute(qc, backend=qasm_sim, repeat=1024, coupling_map=couple_map)

result = job.result()
print(result)
# Out:
# Result(backend_name='qasm_simulator', backend_version='0.7.2', qobj_id='e922939e-c9a4-44e9-8131-533b2ca3d838', job_id='09c1b078-3c48-46dc-ae76-01f52c53a6bc', success=True, results=[ExperimentResult(shots=1024, success=True, meas_level=MeasLevel.CLASSIFIED, data=ExperimentResultData(), header=QobjExperimentHeader(clbit_labels=[], creg_sizes=[], global_phase=0.0, memory_slots=0, metadata=None, n_qubits=3, name='circuit-106', qreg_sizes=[['q', 3]], qubit_labels=[['q', 0], ['q', 1], ['q', 2]]), status=DONE, seed_simulator=3207577801, time_taken=7.24e-05, metadata={'fusion': {'enabled': False}, 'measure_sampling': True, 'method': 'stabilizer', 'parallel_shots': 1, 'parallel_state_update': 8})], date=2021-05-15T23:32:04.075327, status=COMPLETED, status=QobjHeader(backend_name='qasm_simulator', backend_version='0.7.2'), metadata={'max_memory_mb': 15299, 'omp_enabled': True, 'parallel_experiments': 1, 'time_taken': 0.0001931}, time_taken=0.0)

# %%
qc = QuantumCircuit(3)

# Insert code fragment here
qasm_sim = Aer.get_backend('qasm_simulator')
couple_map = [[0, 1], [1, 2]]
job = execute(backend=qasm_sim, qc, shot=1024, coupling_map=couple_map)

result = job.result()
print(result)
# Out:
#   File "<ipython-input-19-aff4da8c4ff5>", line 6
#     job = execute(backend=qasm_sim, qc, shot=1024, coupling_map=couple_map)
#                                    ^
# SyntaxError: positional argument follows keyword argument

# %% [markdown]
# # 15
# Which of these would execute a circuit on a set of qubits which are coupled in a custom way?
# ```
# from qiskit import QuantumCircuit, execute, BasicAer
# backend = BasicAer.get_backend('qasm_simulator')
# qc = QuantumCircuit(3)
# # insert code here
# ```

# %%
backend = BasicAer.get_backend('qasm_simulator')
qc = QuantumCircuit(3)
# insert code here
execute(qc, backend, shots=1024, coupling_map=[[0, 1], [1, 2]])
# Out:
# No classical registers in circuit "circuit-108", counts will be empty.

# %%
backend = BasicAer.get_backend('qasm_simulator')
qc = QuantumCircuit(3)
# insert code here
execute(qc, backend, shots=1024, custom_topology=[[0, 1], [2, 3]])
# Out:
# C:\Users\DaikiMurata\anaconda3\lib\site-packages\qiskit\execute_function.py:343: UserWarning: Option custom_topology is not used by this backend
#   job = backend.run(experiments, **run_kwargs)
# No classical registers in circuit "circuit-110", counts will be empty.

# %%
backend = BasicAer.get_backend('qasm_simulator')
qc = QuantumCircuit(3)
# insert code here
execute(qc, backend, shots=1024, device="qasm_simulator", mode="custom")
# Out:
# C:\Users\DaikiMurata\anaconda3\lib\site-packages\qiskit\execute_function.py:343: UserWarning: Option device is not used by this backend
#   job = backend.run(experiments, **run_kwargs)
# C:\Users\DaikiMurata\anaconda3\lib\site-packages\qiskit\execute_function.py:343: UserWarning: Option mode is not used by this backend
#   job = backend.run(experiments, **run_kwargs)
# No classical registers in circuit "circuit-112", counts will be empty.

# %%
backend = BasicAer.get_backend('qasm_simulator')
qc = QuantumCircuit(3)
# insert code here
execute(qc, backend, mode="custom")
# Out:
# No classical registers in circuit "circuit-114", counts will be empty.

# %% [markdown]
# # 18
# Which code fragment would yield an operator that represents a single-qubit X gate?

# %%
op = Operator.Xop(0)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-007763675d6f> in <module>
# ----> 1 op = Operator.Xop(0)
#
# AttributeError: type object 'Operator' has no attribute 'Xop'

# %%
qc = QuantumCircuit(1)
op = Operator([[0, 1]])
qc.append(op)
# Out:
# ---------------------------------------------------------------------------
# ExtensionError                            Traceback (most recent call last)
# <ipython-input-25-f2c87faa1534> in <module>
#       1 qc = QuantumCircuit(1)
#       2 op = Operator([[0, 1]])
# ----> 3 qc.append(op)
#
# ~\anaconda3\lib\site-packages\qiskit\circuit\quantumcircuit.py in append(self, instruction, qargs, cargs)
#     998                                'have a to_instruction() method.')
#     999         if not isinstance(instruction, Instruction) and hasattr(instruction, "to_instruction"):
# -> 1000             instruction = instruction.to_instruction()
#    1001
#    1002         # Make copy of parameterized gate instances
#
# ~\anaconda3\lib\site-packages\qiskit\quantum_info\operators\operator.py in to_instruction(self)
#     203         # pylint: disable=cyclic-import
#     204         from qiskit.extensions.unitary import UnitaryGate
# --> 205         return UnitaryGate(self.data)
#     206
#     207     def conjugate(self):
#
# ~\anaconda3\lib\site-packages\qiskit\extensions\unitary.py in __init__(self, data, label)
#      60         # Check input is unitary
#      61         if not is_unitary_matrix(data):
# ---> 62             raise ExtensionError("Input matrix is not unitary.")
#      63         # Check input is N-qubit matrix
#      64         input_dim, output_dim = data.shape
#
# ExtensionError: 'Input matrix is not unitary.'

# %% [markdown]
# # 19
# What would be the fidelity result(s) for these two operators, which differ only by global phase?
# ```
# op_a = Operator(XGate())
# op_b = numpy.exp(1j * 0.5) * Operator(XGate())
# ```

# %% [markdown]
# **Fidelty(忠実度)**:2状態の類似度を表す指標
# $$F(\rho_1, \rho_2) = Tr[\sqrt{\sqrt{\rho_1}\rho_2\sqrt{\rho_1}}]^2$$
# 状態が純粋状態の場合、
# $$F = |\langle\psi_1|\psi_2\rangle|^2$$

# %%
qc_a = QuantumCircuit(1)
op_a = Operator(XGate())
qc_a.append(op_a, [0])
state_a = Statevector.from_instruction(qc_a)


qc_b = QuantumCircuit(1)
op_b = numpy.exp(1j * 0.5) * Operator(XGate())
qc_b.append(op_b, [0])
state_b = Statevector.from_instruction(qc_b)

state_fidelity(state_a, state_b)
# Out:
# 1.0

# %% [markdown]
# `process_fidelity` is an information theoretic quantity for how close two quantum channels are to each other, and in the case of unitary operators it does not depend on global phase.
#
# $$F_{process}(\epsilon, U) = \frac{Tr[S^\dagger_US_{\epsilon}]}{d^2}$$

# %%
process_fidelity(op_a, op_b)
# Out:
# 1.0

# %% [markdown]
# $$F_{ave} = \frac{dF_{pro}(\epsilon, U)+1}{d+1}$$
# $F_{pro}(\epsilon, U)$は2チャンネルのprocess_fidelity

# %%
average_gate_fidelity(op_a, op_b)
# Out:
# 1.0

# %% [markdown]
# # 20
# Given this code fragment, which output fits most closely with the measurement probability distribution?
# ```
# qc = QuantumCircuit(2, 2)
# qc.x(0)
# qc.measure([0,1], [0,1])
# simulator = Aer.get_backend('qasm_simulator')
# result = execute(qc, simulator, shots=1000).result()
# counts = result.get_counts(qc)
# print(counts)
# ```

# %%
qc = QuantumCircuit(2, 2)
qc.x(0)
qc.measure([0,1], [0,1])
simulator = Aer.get_backend('qasm_simulator')
result = execute(qc, simulator, shots=1000).result()
counts = result.get_counts(qc)
print(counts)
# Out:
# {'01': 1000}
